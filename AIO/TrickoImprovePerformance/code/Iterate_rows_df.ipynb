# %%
# !pip install ipython-autotime
# %load_ext autotime

# %%
import pandas as pd
# Out:
# time: 654 ms (started: 2023-07-19 07:42:50 +00:00)

# %%
# !gdown --id 17Nsc839o1hcVZDIXpDZ0oGS4DZr9nmwx
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=17Nsc839o1hcVZDIXpDZ0oGS4DZr9nmwx
# To: /content/data_demo.csv
# 100% 12.1M/12.1M [00:00<00:00, 47.8MB/s]
# time: 1.72 s (started: 2023-07-19 07:51:47 +00:00)

# %%
df = pd.read_csv("data_demo.csv")
df.shape
# Out:
# (319735, 1)
# time: 292 ms (started: 2023-07-19 07:51:55 +00:00)

# %% [markdown]
# # Iterrows

# %%
def iterrows(df):
    list_id = []
    for index, row in df.iterrows():
        list_id.append(row["id"])

    return list_id
# Out:
# time: 1.04 ms (started: 2023-07-19 07:52:15 +00:00)

# %%
list_id = iterrows(df)
# Out:
# time: 17.1 s (started: 2023-07-19 07:53:47 +00:00)

# %%
len(list_id)
# Out:
# 319735
# time: 3.42 ms (started: 2023-07-19 07:54:05 +00:00)

# %% [markdown]
# # Optimize

# %%
def np_vectorization(df):
    np_arr = df.to_numpy()

    return np_arr[:,0]
# Out:
# time: 738 µs (started: 2023-07-19 07:54:53 +00:00)

# %%
list_id = np_vectorization(df)
# Out:
# time: 939 µs (started: 2023-07-19 07:54:58 +00:00)
