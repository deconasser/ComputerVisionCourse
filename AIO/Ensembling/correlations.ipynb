# %%
# !gdown --id 1AgwhNclNbPXCzDydhIO20s03XQuop3UI
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1AgwhNclNbPXCzDydhIO20s03XQuop3UI
# To: /content/samples.zip
# 100% 1.31k/1.31k [00:00<00:00, 7.35MB/s]

# %%
# !unzip samples.zip
# Out:
# Archive:  samples.zip
#    creating: samples/
#   inflating: samples/method1.csv
#   inflating: samples/method2.csv
#   inflating: samples/method3.csv
#   inflating: samples/_w2_method2.csv
#   inflating: samples/_w2_method3.csv
#   inflating: samples/_w3_method1.csv

# %%
import pandas as pd

def ensembling(first_file, second_file):
  first_df = pd.read_csv(first_file, index_col=0)
  second_df = pd.read_csv(second_file, index_col=0)
  prediction = first_df.columns[0]
  # correlation
  print("Finding correlation between: {} and {}".format(first_file, second_file))
  print("Column to be measured: {}".format(prediction))
  print("Pearson's correlation score: {}".format(first_df[prediction].corr(second_df[prediction], method='pearson')))
  print("Kendall's correlation score: {}".format(first_df[prediction].corr(second_df[prediction], method='kendall')))
  print("Spearman's correlation score: {}".format(first_df[prediction].corr(second_df[prediction], method='spearman')))

# %%
ensembling("samples/method1.csv", "samples/method2.csv")
# Out:
# Finding correlation between: samples/method1.csv and samples/method2.csv
# Column to be measured: Label
# Pearson's correlation score: 0.6789849863598809
# Kendall's correlation score: 0.6666666666666666
# Spearman's correlation score: 0.7105263157894738
